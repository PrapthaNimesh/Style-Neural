# %% [markdown]
# #Style Transfer
# Style transfer is the process of applying one texture (the Style image) to the content of another image (the Content image). You probably saw it a few years ago when there were a bunch of apps that would convert your selfies to Starry Night images. It quickly (immediately?) became cliché and made style transfer look like a fad, but I maintain style transfer is a really cool tool in the hands of artists.

# %% [markdown]
# ##Set up our Runtime
# Colab needs to know we need to use a GPU-powered machine in order to do style transfers. At the top of this page, click on the `Runtime` tab, then select `Change runtime type`. In the modal that pops up, select `GPU` under the `Hardware accelerator` options.
#
# We then need to make sure we’re using the latest version of Tensorflow 1, otherwise we get some annoying messages.

# %%
#install TF 1.15 to avoid some annoying warning messages
# Restart runtime using 'Runtime' -> 'Restart runtime...'
# %tensorflow_version 1.x
import tensorflow as tf
print(tf.__version__)
# Out:
# TensorFlow 1.x selected.
# 1.15.2

# %% [markdown]
# ##Install the Style-Neural library
# We’re going to work with the library called Neural Style.

# %%
#import some image display tools
from IPython.display import Image, display
#install the library in colab
# !git clone https://github.com/PrapthaNimesh/Style-Neural
#change into that directory
# %cd Style-Neural/
#install the library dependencies (it's likely Colab already has them installed, but let's be sure)
# !pip install -r requirements.txt
#install the VGG19  model
# !wget http://www.vlfeat.org/matconvnet/models/imagenet-vgg-verydeep-19.mat
# Out:
# Cloning into 'Style-Neural'...
# remote: Enumerating objects: 19, done.
# remote: Counting objects: 100% (19/19), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 19 (delta 1), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (19/19), done.
# /content/Style-Neural
# Requirement already satisfied: opencv-python>=4.1.1.26 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 1)) (4.1.2.30)
# Requirement already satisfied: scipy>=1.3.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 2)) (1.4.1)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from opencv-python>=4.1.1.26->-r requirements.txt (line 1)) (1.21.5)
# --2022-04-17 17:48:14--  http://www.vlfeat.org/matconvnet/models/imagenet-vgg-verydeep-19.mat
# Resolving www.vlfeat.org (www.vlfeat.org)... 64.90.48.57
# Connecting to www.vlfeat.org (www.vlfeat.org)|64.90.48.57|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://www.vlfeat.org/matconvnet/models/imagenet-vgg-verydeep-19.mat [following]
# --2022-04-17 17:48:14--  https://www.vlfeat.org/matconvnet/models/imagenet-vgg-verydeep-19.mat
# Connecting to www.vlfeat.org (www.vlfeat.org)|64.90.48.57|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 534904783 (510M)
# Saving to: ‘imagenet-vgg-verydeep-19.mat’
#
# imagenet-vgg-veryde 100%[===================>] 510.12M  22.9MB/s    in 23s
#
# 2022-04-17 17:48:38 (22.1 MB/s) - ‘imagenet-vgg-verydeep-19.mat’ saved [534904783/534904783]

# %%
#let's make sure we're in the right folder
# !pwd
# we should see "/content/Style-Neural"

# %%
# !python neural_style.py --content_img face.jpg --style_imgs the_scream.jpg
# Out:
# ---- RENDERING SINGLE IMAGE ----
#
# 2022-04-17 18:14:33.520994: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2022-04-17 18:14:33.547000: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-17 18:14:33.547758: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# 2022-04-17 18:14:33.548048: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2022-04-17 18:14:33.549929: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2022-04-17 18:14:33.551050: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2022-04-17 18:14:33.551450: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2022-04-17 18:14:33.553604: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2022-04-17 18:14:33.554480: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2022-04-17 18:14:33.558309: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2022-04-17 18:14:33.558415: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-17 18:14:33.559265: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-17 18:14:33.559962: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2022-04-17 18:14:33.564683: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2299995000 Hz
# 2022-04-17 18:14:33.564948: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x5584dae35640 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2022-04-17 18:14:33.564982: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2022-04-17 18:14:33.663596: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-17 18:14:33.664461: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x5584dae35800 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2022-04-17 18:14:33.664498: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla K80, Compute Capability 3.7
# 2022-04-17 18:14:33.664782: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-17 18:14:33.665607: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# 2022-04-17 18:14:33.665687: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2022-04-17 18:14:33.665729: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2022-04-17 18:14:33.665779: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2022-04-17 18:14:33.665822: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2022-04-17 18:14:33.665861: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2022-04-17 18:14:33.665902: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2022-04-17 18:14:33.665958: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2022-04-17 18:14:33.666048: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-17 18:14:33.666856: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-17 18:14:33.667581: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2022-04-17 18:14:33.667663: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2022-04-17 18:14:33.668957: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1180] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-04-17 18:14:33.668987: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1186]      0
# 2022-04-17 18:14:33.669003: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1199] 0:   N
# 2022-04-17 18:14:33.669130: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-17 18:14:33.669901: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-17 18:14:33.670569: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2022-04-17 18:14:33.670615: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1325] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10813 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7)
# WARNING:tensorflow:From neural_style.py:333: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# 2022-04-17 18:14:38.674908: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2022-04-17 18:14:39.357010: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/math_grad.py:1375: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From neural_style.py:610: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# Single image elapsed time: 300.5604736804962

# %%
listOfImageNames = ['image_output/1000/content.png',
                    'image_output/1000/style_0.png',
                    'image_output/1000/image_output-1000.png']

for imageName in listOfImageNames:
    display(Image(filename=imageName))

# %% [markdown]
# Change the path

# %%
Image(filename='{path/to/image}')
